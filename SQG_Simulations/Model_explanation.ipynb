# %% [markdown]
# # Explantion
#
# reconstruct the three-dimensional ocean circulation from surface observations using the Surface Quasi-Geostrophic (SQG) framework.

# %% [markdown]
# This simulation goes as follow :
#
# 1. Define the first and zero-th order potentials.
# $$ \Phi^0 $$
# and
# $$ \Phi^1 \quad F^1 \quad G^1 $$
# I also plan to add some white noise to the system. There three potentials should be function of spacial position $\vec{x}$ and time $t$.
#
# 2. Use the SQG+1 model to obtain the Surface Sea Height data.
#
# 3. Ust eh SQG+1 model to do the inversion and obtain the original potential field.

# %% [markdown]
# The surface sea height data is purely determined by the zero-th order $\Phi^0$ by the formula :
# $$ \widehat{\Phi}^0=\frac{\hat{b}^{0, t}}{f \mu} e^{\mu z} $$
#
# So I think it is better if I define the surface buoyancy directly. Then
